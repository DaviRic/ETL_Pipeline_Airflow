# %%
import psycopg2
db_name = 'food_db'
db_user = 'postgres'
db_password = '123'
db_host = 'localhost'
db_port = '5432'

try:
    conn = psycopg2.connect(
        dbname = db_name,
        user = db_user,
        password = db_password,
        host = db_host,
        port = db_port
    )
    print("Conexão bem-sucedida!")
except Exception as e:
    print(f'Erro ao conectar com o banco de dados: {e}')
# Out:
# Conexão bem-sucedida!

# %%
import pandas as pd
path = '/home/davicruvel/airflow_project/datasets/consolidated_files/consolidated_food_main.xlsx'
df = pd.read_excel(path)
df.head(100)
# Out:
#        Category  Avg_Retail_price        Unit  Prep_Yield_Factor  Cup_Size  \
# 0       Product          1.462360   per pound           0.680000  0.407855
# 1   Subcategory          1.057161    per pint           1.000000  8.000000
# 2   Subcategory          0.733781    per pint           1.000000  8.000000
# 3       Product          0.597117   per pound           0.640000  0.330693
# 4       Product          5.749907   per pound           1.000000  0.165347
# ..          ...               ...         ...                ...       ...
# 95      Product          1.864196   per pound           1.000000  0.540133
# 96  Subcategory          2.184103   per pound           0.892619  0.275578
# 97  Subcategory          2.397390   per pound           0.930351  0.275578
# 98      Product          1.635948   per pound           0.769500  0.396832
# 99      Product          1.812581   per pound           0.900000  0.275578
#
#         Cup_Unit  Avg_Price_Cup  food_type
# 0         Pounds       0.877105      fruit
# 1   Fluid ounces       0.528581      fruit
# 2   Fluid ounces       0.366890      fruit
# 3         Pounds       0.308535      fruit
# 4         Pounds       0.950728      fruit
# ..           ...            ...        ...
# 95        Pounds       1.006913  vegetable
# 96        Pounds       0.674297  vegetable
# 97        Pounds       0.710127  vegetable
# 98        Pounds       0.843660  vegetable
# 99        Pounds       0.555008  vegetable
#
# [100 rows x 8 columns]
